# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
months = ['Jan', 'Feb', 'Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
mon_precip = [5.5, 6.2, 5.5, 1.4, 0.7, 0.1, 0.2, 0.3, 0.3, 1.4, 2.9, 3.0]

fig, ax = plt.subplots()
bar_container = ax.bar(months, mon_precip)
ax.set(ylabel='Precipitation in mm', title='Cairo precipitation in a Month', ylim=(0, 20))
# Out:
# "ax.bar_label(bar_container, fmt='{:,.1f} mm')"
