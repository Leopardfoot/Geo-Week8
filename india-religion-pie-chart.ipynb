# %%
import matplotlib.pyplot as plt

explode = (0.1, 0, 0, 0, 0)
labels = 'Hinduism', 'Islam', 'Christianity', 'Sikhism', 'Other'
sizes = [79.8, 14.2, 2.3, 1.7, 2]

fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x16b58e9d3d0>,
# ...
#  [Text(-0.9663695470467539, 0.711428069829025, 'Hinduism'),
#   Text(0.7479489192837477, -0.8065806928896042, 'Islam'),
#   Text(1.049319403429116, -0.33004361770403057, 'Christianity'),
#   Text(1.0824106409368497, -0.19592652803201116, 'Sikhism'),
#   Text(1.097829419959995, -0.06906927443010473, 'Other')],
#  [Text(-0.5637155691106064, 0.4149997074002645, '79.8%'),
#   Text(0.40797213779113506, -0.43995310521251135, '14.2%'),
#   Text(0.5723560382340632, -0.18002379147492573, '2.3%'),
#   Text(0.5904058041473725, -0.1068690152901879, '1.7%'),
#   Text(0.5988160472509063, -0.037674149689148034, '2.0%')])
